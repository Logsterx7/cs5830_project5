# %%
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_recall_fscore_support
from sklearn import datasets
from sklearn.naive_bayes import GaussianNB
import pandas as pd

##setting up data
data = pd.read_csv("apple_quality.csv")
data = data.dropna()
data = data.drop('A_id',axis=1)
data['Acidity'] = data['Acidity'].astype(float)

##Data training preperation
X = data.drop('Quality', axis=1)  # Features

y = data['Quality']  # Target variable
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

#Train the Gaussian Naive Bayes classifier
gnb = GaussianNB()
gnb.fit(X_train, y_train)

#Evaluate the Model
y_pred = gnb.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

##results
gnb.fit(X_train, y_train)
y_pred = gnb.predict(X_test)
p,r,f,s = precision_recall_fscore_support(y_test, y_pred)
print(p, r, f)
data

# %%
##split up good and bad apples
goodApples = data[data.Quality == 'good']
badApples = data[data.Quality == 'bad']
print(len(goodApples))
print(len(badApples))


import requests , json
import pandas as pd
import seaborn as sns
import statistics as stat
from scipy import stats

##CRUNCHINESS

##standard_deviation = goodApples[''].std()


##CRUNCHINESS

##size - small p value
##weight - big p value *
##ripeness - very small p value
##sweetness - very small p value
##crunchiness - very big p value *

sns.set_theme(style="white")
plot = sns.displot(data=data, x="Crunchiness", hue="Quality", kind="kde", alpha=.8, palette="muted", common_norm=True)
plot.set(xlabel='Crunchiness', ylabel='Density')

## T-Test:
crunchiness_good = goodApples['Crunchiness']
crunchiness_bad = badApples['Crunchiness']

# Perform the T-Test
t_stat, p_value = stats.ttest_ind(crunchiness_good, crunchiness_bad, equal_var=True)


print("Standard deviation for good apples: "+ str(goodApples['Crunchiness'].std()))
print("Standard deviation for bad apples: "+ str(badApples['Crunchiness'].std()))

print("Mean for good apples: "+ str(goodApples['Crunchiness'].mean()))
print("Mean for bad apples: "+ str(badApples['Crunchiness'].mean()))
print("T-Statistic:", t_stat)
print("P-Value:", p_value)

# %%
##SWEETNESS

plot = sns.displot(data=data, x="Sweetness", hue="Quality", kind="kde", alpha=.8, palette="muted", common_norm=True)
plot.set(xlabel='Sweetness', ylabel='Density')

## T-Test:
sweetness_good = goodApples['Sweetness']
sweetness_bad = badApples['Sweetness']

# Perform the T-Test
t_stat, p_value = stats.ttest_ind(sweetness_good, sweetness_bad, equal_var=True)

print("Standard deviation for good apples: "+ str(goodApples['Sweetness'].std()))
print("Standard deviation for bad apples: "+ str(badApples['Sweetness'].std()))
print("Mean for good apples: "+ str(goodApples['Sweetness'].mean()))
print("Mean for bad apples: "+ str(badApples['Sweetness'].mean()))

print("T-Statistic:", t_stat)
print("P-Value:", p_value)

# %%
##JUICINESS

plot = sns.displot(data=data, x="Juiciness", hue="Quality", kind="kde", alpha=.8, palette="muted", common_norm=True)
plot.set(xlabel='Juiciness', ylabel='Density')

## T-Test:
juiciness_good = goodApples['Juiciness']
juiciness_bad = badApples['Juiciness']

# Perform the T-Test
t_stat, p_value = stats.ttest_ind(juiciness_good, juiciness_bad, equal_var=True)


print("Standard deviation for good apples: "+ str(goodApples['Juiciness'].std()))
print("Standard deviation for bad apples: "+ str(badApples['Juiciness'].std()))
print("Mean for good apples: "+ str(goodApples['Juiciness'].mean()))
print("Mean for bad apples: "+ str(badApples['Juiciness'].mean()))

print("T-Statistic:", t_stat)
print("P-Value:", p_value)

# %%
##RIPENESS

plot = sns.displot(data=data, x="Ripeness", hue="Quality", kind="kde", alpha=.8, palette="muted", common_norm=True)
plot.set(xlabel='Ripeness', ylabel='Density')

## T-Test:
ripeness_good = goodApples['Ripeness']
ripeness_bad = badApples['Ripeness']

# Perform the T-Test
t_stat, p_value = stats.ttest_ind(juiciness_good, juiciness_bad, equal_var=True)


print("Standard deviation for good apples: "+ str(goodApples['Ripeness'].std()))
print("Standard deviation for bad apples: "+ str(badApples['Ripeness'].std()))
print("Mean for good apples: "+ str(goodApples['Ripeness'].mean()))
print("Mean for bad apples: "+ str(badApples['Ripeness'].mean()))
print("T-Statistic:", t_stat)
print("P-Value:", p_value)

# %%
##WEIGHT
plot = sns.displot(data=data, x="Weight", hue="Quality", kind="kde", alpha=.8, palette="muted", common_norm=True)
plot.set(xlabel='Weight', ylabel='Density')

## T-Test:
weight_good = goodApples['Weight']
weight_bad = badApples['Weight']

# Perform the T-Test
t_stat, p_value = stats.ttest_ind(weight_good, weight_bad, equal_var=True)


print("Standard deviation for good apples: "+ str(goodApples['Weight'].std()))
print("Standard deviation for bad apples: "+ str(badApples['Weight'].std()))
print("Mean for good apples: "+ str(goodApples['Weight'].mean()))
print("Mean for bad apples: "+ str(badApples['Weight'].mean()))
print("T-Statistic:", t_stat)
print("P-Value:", p_value)

# %%
##SIZE
plot = sns.displot(data=data, x="Size", hue="Quality", kind="kde", alpha=.8, palette="muted", common_norm=True)
plot.set(xlabel='Size', ylabel='Density')

## T-Test:
size_good = goodApples['Size']
size_bad = badApples['Size']

# Perform the T-Test
t_stat, p_value = stats.ttest_ind(size_good, size_bad, equal_var=True)


print("Standard deviation for good apples: "+ str(goodApples['Size'].std()))
print("Standard deviation for bad apples: "+ str(badApples['Size'].std()))
print("Mean for good apples: "+ str(goodApples['Size'].mean()))
print("Mean for bad apples: "+ str(badApples['Size'].mean()))
print("T-Statistic:", t_stat)
print("P-Value:", p_value)

# %%
##ACIDITY
## T-Test:
acidity_good = goodApples['Acidity']
acidity_bad = badApples['Acidity']

# Perform the T-Test
t_stat, p_value = stats.ttest_ind(acidity_good, acidity_bad, equal_var=True)


plot = sns.displot(data=data, x="Acidity", hue="Quality", kind="kde", alpha=.8, palette="muted", common_norm=True)

print("Standard deviation for good apples: "+ str(goodApples['Acidity'].std()))
print("Standard deviation for bad apples: "+ str(badApples['Acidity'].std()))
print("Mean for good apples: "+ str(goodApples['Acidity'].mean()))
print("Mean for bad apples: "+ str(badApples['Acidity'].mean()))

print("T-Statistic:", t_stat)
print("P-Value:", p_value)
